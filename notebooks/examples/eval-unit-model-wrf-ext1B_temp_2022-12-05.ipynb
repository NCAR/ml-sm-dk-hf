# %% [markdown]
# # Evaluate Unit-wget model over MPI and Era
#
#
# ### Per-filter Variance tables

# %%
for ff in top5_filters[0:15]:
    print("\nFilter {}:".format(ff))
    print('Vars:', varnames[0:9])
    row = 1
    for topii in range(5):
        print('ROW {}:\t'.format(row), end=''); row+=1
        for vv in range(10):
            #for xx in list(sorted(err1_list, key=lambda x: x[0], reverse=True))[0:365]:
            xx = list(sorted(err1_list, key=lambda x: x[1][vv], reverse=True))[topii]
            fvar = xx[1][vv]
            print('{}\t'.format(fvar), end='')
        print()
        
    print("\nFilter {}:".format(ff))
    print('Vars:', varnames[9:18])
    row = 1
    for topii in range(5):
        print('ROW {}:\t'.format(row), end=''); row+=1
        for vv in range(9,18):
            #for xx in list(sorted(err1_list, key=lambda x: x[0], reverse=True))[0:365]:
            xx = list(sorted(err1_list, key=lambda x: x[1][vv], reverse=True))[topii]
            fvar = xx[1][vv]
            print('{}\t'.format(fvar), end='')
        print()
# Out:
# Filter 15:
# Vars: ['U850', 'V850', 'Q850', 'T700', 'Z700', 'Z500', 'U250', 'V250', 'prec']
# ROW 1:	0.00565	0.0115	0.0154	0.0058	0.00954	0.00494	0.00644	0.0104	0.0167	0.00621
# ROW 2:	0.00503	0.00528	0.0139	0.00423	0.00436	0.00483	0.00539	0.00704	0.00668	0.00201
# ROW 3:	0.00432	0.00514	0.0132	0.00375	0.00423	0.00418	0.00529	0.00403	0.00654	0.00198
# ROW 4:	0.00404	0.00409	0.00648	0.00349	0.00197	0.00279	0.0038	0.00402	0.00613	0.0019
# ROW 5:	0.00312	0.00381	0.00546	0.00277	0.00189	0.00233	0.00359	0.00356	0.00554	0.00174
#
# Filter 15:
# Vars: ['tmax', 'tmin', 'uas', 'vas', 'huss', 'rsds', 'orog', 'miss', 'yday']
# ROW 1:	0.00621	0.00638	0.00247	0.00273	0.0105	0.013	0.00411	0.00195	0.0172
# ROW 2:	0.00201	0.00239	0.00206	0.00267	0.00599	0.00491	0.004	0.000918	0.00731
# ROW 3:	0.00198	0.00226	0.00178	0.00225	0.00536	0.00485	0.00361	0.000808	0.00571
# ROW 4:	0.0019	0.0019	0.00168	0.00222	0.00421	0.00448	0.00335	0.000727	0.00511
# ...
